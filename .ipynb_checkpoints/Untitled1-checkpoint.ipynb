# %%
import pandas as pd
# Out:
# 1D Array Elements: [10, 20, 30, 40, 50]
# 2D Array (Matrix):
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:27
#      25 for _dependency in _hard_dependencies:
#      26     try:
# ---> 27         __import__(_dependency)
#      28     except ImportError as _e:  # pragma: no cover
#      29         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~\Desktop\APC-PYTHON(Lab)\numpy.py:39
#      36         print("3D Array:\n", self.arr)
#      38 # Object
# ---> 39 obj3 = ThreeDArray([
#      40     [[1, 2], [3, 4]],
#      41     [[5, 6], [7, 8]]
#      42 ])
#      43 obj3.display()
#
# File ~\Desktop\APC-PYTHON(Lab)\numpy.py:33, in ThreeDArray.__init__(self, elements)
# ...
